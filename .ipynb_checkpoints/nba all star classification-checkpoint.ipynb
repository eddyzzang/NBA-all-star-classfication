# %% [markdown]
# ## NBA all-star classification

# %% [markdown]
# ### Features
# - Season -- If listed as single number, the year the season ended.
# - AllStar - Indicates All-Star for league.
# - Only on regular season tables.
# - Age -- Player's age on February 1 of the season
# - Tm -- Team
# - Lg -- League
# - Pos -- Position
# - G -- Games
# - GS -- Games Started
# - MP -- Minutes Played Per Game
# - FG -- Field Goals Per Game
# - FGA -- Field Goal Attempts Per Game
# - FG% -- Field Goal Percentage
# - 3P -- 3-Point Field Goals Per Game
# - 3PA -- 3-Point Field Goal Attempts Per Game
# - 3P% -- 3-Point Field Goal Percentage
# - 2P -- 2-Point Field Goals Per Game
# - 2PA -- 2-Point Field Goal Attempts Per Game
# - 2P% -- 2-Point Field Goal Percentage
# - eFG% -- Effective Field Goal Percentage
#     - This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.
# - FT -- Free Throws Per Game
# - FTA -- Free Throw Attempts Per Game
# - FT% -- Free Throw Percentage
# - ORB -- Offensive Rebounds Per Game
# - DRB -- Defensive Rebounds Per Game
# - TRB -- Total Rebounds Per Game
# - AST -- Assists Per Game
# - STL -- Steals Per Game
# - BLK -- Blocks Per Game
# - TOV -- Turnovers Per Game
# - PF -- Personal Fouls Per Game
# - PTS -- Points Per Game

# %% [markdown]
# ### Import

# %%
import missingno as msno
from sklearn.impute import SimpleImputer

# %%
nba_df = pd.read_csv('nba_data.csv')
nba_df
# Out:
#        Unnamed: 0  index             Player  AllStar  Season   age Team  \
# 0               0      0     Alaa Abdelnaby        0    1990  22.0  POR
# 1               1      1     Alaa Abdelnaby        0    1991  23.0  POR
# 2               2      2     Alaa Abdelnaby        0    1992  24.0  TOT
# 3               3      3     Alaa Abdelnaby        0    1992  24.0  MIL
# 4               4      4     Alaa Abdelnaby        0    1992  24.0  BOS
# ...           ...    ...                ...      ...     ...   ...  ...
# 24517       24517  18260       George Zídek        0    1997  24.0  SEA
# 24518       24518  18261  Derrick Zimmerman        0    2005  24.0  NJN
# 24519       24519  18262           Jim Zoet        0    1982  29.0  DET
# 24520       24520  18263          Bill Zopf        0    1970  22.0  MIL
# 24521       24521  18264         Matt Zunic        0    1948  29.0  WSC
#
#       League  Pos     G  ...  FTA    FT%  ORB  DRB  TRB  AST  BLK  TOV   PF  \
# 0        NBA   PF  43.0  ...  1.0  0.568  0.6  1.4  2.1  0.3  0.3  0.5  0.9
# 1        NBA   PF  71.0  ...  1.4  0.752  1.1  2.5  3.7  0.4  0.2  0.9  1.9
# 2        NBA   PF  75.0  ...  1.5  0.759  1.7  2.8  4.5  0.4  0.3  1.3  2.5
# 3        NBA   PF  12.0  ...  1.3  0.750  1.0  2.1  3.1  0.8  0.3  1.1  2.0
# 4        NBA   PF  63.0  ...  1.6  0.760  1.8  3.0  4.8  0.3  0.3  1.3  2.6
# ...      ...  ...   ...  ...  ...    ...  ...  ...  ...  ...  ...  ...  ...
# 24517    NBA    C   6.0  ...  0.7  1.000  0.0  0.7  0.7  0.2  0.0  0.2  0.8
# 24518    NBA   PG   2.0  ...  0.0    NaN  0.5  1.5  2.0  3.5  0.0  2.0  2.0
# 24519    NBA    C   7.0  ...  0.0    NaN  0.4  0.7  1.1  0.1  0.4  0.6  1.3
# 24520    NBA   PG  53.0  ...  0.7  0.556  NaN  NaN  0.9  1.4  NaN  NaN  0.6
# 24521    BAA  NaN  56.0  ...  1.9  0.706  NaN  NaN  NaN  0.9  NaN  NaN  3.3
#
#        PTS
# 0      3.1
# 1      6.1
# 2      7.7
# 3      5.3
# 4      8.2
# ...    ...
# 24517  1.8
# 24518  2.0
# 24519  0.3
# 24520  2.2
# 24521  4.9
#
# [24522 rows x 33 columns]

# %% [markdown]
# ### Null data

# %%
msno.matrix(nba_df)
plt.show()

# %% [markdown]
# ### Delete null Position data

# %%
nba_df = nba_df[nba_df['Pos'].isnull() != True]
nba_df
# Out:
#        Unnamed: 0  index             Player  AllStar  Season   age Team  \
# 0               0      0     Alaa Abdelnaby        0    1990  22.0  POR
# 1               1      1     Alaa Abdelnaby        0    1991  23.0  POR
# 2               2      2     Alaa Abdelnaby        0    1992  24.0  TOT
# 3               3      3     Alaa Abdelnaby        0    1992  24.0  MIL
# 4               4      4     Alaa Abdelnaby        0    1992  24.0  BOS
# ...           ...    ...                ...      ...     ...   ...  ...
# 24516       24516  18259       George Zídek        0    1997  24.0  DEN
# 24517       24517  18260       George Zídek        0    1997  24.0  SEA
# 24518       24518  18261  Derrick Zimmerman        0    2005  24.0  NJN
# 24519       24519  18262           Jim Zoet        0    1982  29.0  DET
# 24520       24520  18263          Bill Zopf        0    1970  22.0  MIL
#
#       League Pos     G  ...  FTA    FT%  ORB  DRB  TRB  AST  BLK  TOV   PF  \
# 0        NBA  PF  43.0  ...  1.0  0.568  0.6  1.4  2.1  0.3  0.3  0.5  0.9
# 1        NBA  PF  71.0  ...  1.4  0.752  1.1  2.5  3.7  0.4  0.2  0.9  1.9
# 2        NBA  PF  75.0  ...  1.5  0.759  1.7  2.8  4.5  0.4  0.3  1.3  2.5
# 3        NBA  PF  12.0  ...  1.3  0.750  1.0  2.1  3.1  0.8  0.3  1.1  2.0
# 4        NBA  PF  63.0  ...  1.6  0.760  1.8  3.0  4.8  0.3  0.3  1.3  2.6
# ...      ...  ..   ...  ...  ...    ...  ...  ...  ...  ...  ...  ...  ...
# 24516    NBA   C   6.0  ...  2.0  0.833  0.7  1.5  2.2  0.2  0.3  0.5  0.8
# 24517    NBA   C   6.0  ...  0.7  1.000  0.0  0.7  0.7  0.2  0.0  0.2  0.8
# 24518    NBA  PG   2.0  ...  0.0    NaN  0.5  1.5  2.0  3.5  0.0  2.0  2.0
# 24519    NBA   C   7.0  ...  0.0    NaN  0.4  0.7  1.1  0.1  0.4  0.6  1.3
# 24520    NBA  PG  53.0  ...  0.7  0.556  NaN  NaN  0.9  1.4  NaN  NaN  0.6
#
#        PTS
# 0      3.1
# 1      6.1
# 2      7.7
# 3      5.3
# 4      8.2
# ...    ...
# 24516  3.0
# 24517  1.8
# 24518  2.0
# 24519  0.3
# 24520  2.2
#
# [23348 rows x 33 columns]

# %%
msno.matrix(nba_df)

# %% [markdown]
# ### Replace '-' value to 0

# %%
nba_df.replace(np.nan, 0, inplace=True)

# %%
nba_df
# Out:
#        index             Player  AllStar  Season age Team League Pos   G  GS  \
# 0          0     Alaa Abdelnaby        0    1990  22  POR    NBA  PF  43   0
# 1          1     Alaa Abdelnaby        0    1991  23  POR    NBA  PF  71   1
# 2          2     Alaa Abdelnaby        0    1992  24  TOT    NBA  PF  75  52
# 3          3     Alaa Abdelnaby        0    1992  24  MIL    NBA  PF  12   0
# 4          4     Alaa Abdelnaby        0    1992  24  BOS    NBA  PF  63  52
# ...      ...                ...      ...     ...  ..  ...    ...  ..  ..  ..
# 24516  18259       George Zídek        0    1997  24  DEN    NBA   C   6   0
# 24517  18260       George Zídek        0    1997  24  SEA    NBA   C   6   0
# 24518  18261  Derrick Zimmerman        0    2005  24  NJN    NBA  PG   2   0
# 24519  18262           Jim Zoet        0    1982  29  DET    NBA   C   7   0
# 24520  18263          Bill Zopf        0    1970  22  MIL    NBA  PG  53   0
#
#        ...  FTA    FT%  ORB  DRB  TRB  AST  BLK  TOV   PF  PTS
# 0      ...  1.0   .568  0.6  1.4  2.1  0.3  0.3  0.5  0.9  3.1
# 1      ...  1.4   .752  1.1  2.5  3.7  0.4  0.2  0.9  1.9  6.1
# 2      ...  1.5   .759  1.7  2.8  4.5  0.4  0.3  1.3  2.5  7.7
# 3      ...  1.3   .750  1.0  2.1  3.1  0.8  0.3  1.1  2.0  5.3
# 4      ...  1.6   .760  1.8  3.0  4.8  0.3  0.3  1.3  2.6  8.2
# ...    ...  ...    ...  ...  ...  ...  ...  ...  ...  ...  ...
# 24516  ...  2.0   .833  0.7  1.5  2.2  0.2  0.3  0.5  0.8  3.0
# 24517  ...  0.7  1.000  0.0  0.7  0.7  0.2  0.0  0.2  0.8  1.8
# 24518  ...  0.0      0  0.5  1.5  2.0  3.5  0.0  2.0  2.0  2.0
# 24519  ...  0.0      0  0.4  0.7  1.1  0.1  0.4  0.6  1.3  0.3
# 24520  ...  0.7   .556    0    0  0.9  1.4    0    0  0.6  2.2
#
# [23348 rows x 32 columns]

# %%
nba_df.columns
# Out:
# Index(['index', 'Player', 'AllStar', 'Season', 'age', 'Team', 'League', 'Pos',
#        'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK',
#        'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ### Change object type to int type

# %%
nba_df[['MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK', 'TOV', 'PF', 'PTS']] = nba_df[['MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK', 'TOV', 'PF', 'PTS']].astype(str).astype(float)

# %%
nba_df[['Season', 'age', 'G', 'GS']] = nba_df[['Season', 'age', 'G', 'GS']].astype(int)

# %%
nba_df = nba_df.reset_index().drop(['level_0', 'index'], axis=1)

# %% [markdown]
# ### Delete all other League players other than NBA

# %%
nba_df = nba_df[nba_df['League']=='NBA'].reset_index(drop=True)

# %% [markdown]
# ### Describe dataset

# %%
nba_df.describe()
# Out:
#             AllStar        Season           age             G            GS  \
# count  21742.000000  21742.000000  21742.000000  21742.000000  21742.000000
# mean       0.068163   1990.125517     26.958651     50.756646     16.522767
# std        0.252031     16.059621      3.861153     26.605477     26.222241
# min        0.000000   1949.000000     18.000000      0.000000      0.000000
# 25%        0.000000   1979.000000     24.000000     27.000000      0.000000
# 50%        0.000000   1993.000000     26.000000     57.000000      1.000000
# 75%        0.000000   2003.000000     30.000000     76.000000     23.000000
# max        1.000000   2018.000000     44.000000     88.000000     83.000000
#
#                  MP            FG           FGA           FG%            3P  \
# count  21742.000000  21742.000000  21742.000000  21742.000000  21742.000000
# mean      19.983645      3.157939      7.077872      0.429199      0.246251
# std       10.551056      2.330113      4.862766      0.099675      0.472138
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       11.225000      1.300000      3.200000      0.392000      0.000000
# 50%       19.100000      2.600000      5.900000      0.439000      0.000000
# 75%       28.700000      4.500000      9.900000      0.480000      0.300000
# max       48.500000     20.000000     39.500000      1.000000      3.400000
#
#        ...           FTA           FT%           ORB           DRB  \
# count  ...  21742.000000  21742.000000  21742.000000  21742.000000
# mean   ...      2.243952      0.691173      0.895212      2.038543
# std    ...      1.885922      0.195032      0.894262      1.884605
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.900000      0.642000      0.200000      0.700000
# 50%    ...      1.700000      0.736000      0.600000      1.600000
# 75%    ...      3.100000      0.804000      1.300000      2.900000
# max    ...     17.000000      1.000000      7.200000     13.700000
#
#                 TRB           AST           BLK           TOV            PF  \
# count  21742.000000  21742.000000  21742.000000  21742.000000  21742.000000
# mean       3.703072      1.878797      0.338833      1.001053      2.050377
# std        2.893408      1.793250      0.495293      0.900622      0.928610
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.700000      0.600000      0.000000      0.200000      1.400000
# 50%        2.900000      1.300000      0.200000      0.800000      2.000000
# 75%        4.900000      2.600000      0.400000      1.500000      2.700000
# max       27.200000     14.500000      5.600000      5.700000      6.000000
#
#                 PTS
# count  21742.000000
# mean       8.219938
# std        6.087987
# min        0.000000
# 25%        3.500000
# 50%        6.600000
# 75%       11.600000
# max       50.400000
#
# [8 rows x 27 columns]

# %%
nba_df.drop(['League', 'Team'], axis=1, inplace=True)

# %% [markdown]
# ### AllStar Count

# %%
sns.countplot(x='AllStar', data=nba_df)

# %% [markdown]
# ### Position Count

# %%
sns.countplot(x='Pos', data=nba_df)

# %%
nba_df
# Out:
#                   Player  AllStar  Season  age Pos   G  GS    MP   FG  FGA  \
# 0         Alaa Abdelnaby        0    1990   22  PF  43   0   6.7  1.3  2.7
# 1         Alaa Abdelnaby        0    1991   23  PF  71   1  13.2  2.5  5.1
# 2         Alaa Abdelnaby        0    1992   24  PF  75  52  17.5  3.3  6.3
# 3         Alaa Abdelnaby        0    1992   24  PF  12   0  13.3  2.2  4.7
# 4         Alaa Abdelnaby        0    1992   24  PF  63  52  18.3  3.5  6.6
# ...                  ...      ...     ...  ...  ..  ..  ..   ...  ...  ...
# 21737       George Zídek        0    1997   24   C   6   0   7.0  0.7  2.5
# 21738       George Zídek        0    1997   24   C   6   0   3.7  0.5  2.3
# 21739  Derrick Zimmerman        0    2005   24  PG   2   0  16.0  1.0  1.5
# 21740           Jim Zoet        0    1982   29   C   7   0   4.3  0.1  0.7
# 21741          Bill Zopf        0    1970   22  PG  53   0   7.5  0.9  2.5
#
#        ...  FTA    FT%  ORB  DRB  TRB  AST  BLK  TOV   PF  PTS
# 0      ...  1.0  0.568  0.6  1.4  2.1  0.3  0.3  0.5  0.9  3.1
# 1      ...  1.4  0.752  1.1  2.5  3.7  0.4  0.2  0.9  1.9  6.1
# 2      ...  1.5  0.759  1.7  2.8  4.5  0.4  0.3  1.3  2.5  7.7
# 3      ...  1.3  0.750  1.0  2.1  3.1  0.8  0.3  1.1  2.0  5.3
# 4      ...  1.6  0.760  1.8  3.0  4.8  0.3  0.3  1.3  2.6  8.2
# ...    ...  ...    ...  ...  ...  ...  ...  ...  ...  ...  ...
# 21737  ...  2.0  0.833  0.7  1.5  2.2  0.2  0.3  0.5  0.8  3.0
# 21738  ...  0.7  1.000  0.0  0.7  0.7  0.2  0.0  0.2  0.8  1.8
# 21739  ...  0.0  0.000  0.5  1.5  2.0  3.5  0.0  2.0  2.0  2.0
# 21740  ...  0.0  0.000  0.4  0.7  1.1  0.1  0.4  0.6  1.3  0.3
# 21741  ...  0.7  0.556  0.0  0.0  0.9  1.4  0.0  0.0  0.6  2.2
#
# [21742 rows x 29 columns]
