# %% [markdown]
# ## NBA all-star classification

# %% [markdown]
# ### Features
# - Season -- If listed as single number, the year the season ended.
# - AllStar - Indicates All-Star for league.
# - Only on regular season tables.
# - Age -- Player's age on February 1 of the season
# - Tm -- Team
# - Lg -- League
# - Pos -- Position
# - G -- Games
# - GS -- Games Started
# - MP -- Minutes Played Per Game
# - FG -- Field Goals Per Game
# - FGA -- Field Goal Attempts Per Game
# - FG% -- Field Goal Percentage
# - 3P -- 3-Point Field Goals Per Game
# - 3PA -- 3-Point Field Goal Attempts Per Game
# - 3P% -- 3-Point Field Goal Percentage
# - 2P -- 2-Point Field Goals Per Game
# - 2PA -- 2-Point Field Goal Attempts Per Game
# - 2P% -- 2-Point Field Goal Percentage
# - eFG% -- Effective Field Goal Percentage
#     - This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.
# - FT -- Free Throws Per Game
# - FTA -- Free Throw Attempts Per Game
# - FT% -- Free Throw Percentage
# - ORB -- Offensive Rebounds Per Game
# - DRB -- Defensive Rebounds Per Game
# - TRB -- Total Rebounds Per Game
# - AST -- Assists Per Game
# - STL -- Steals Per Game
# - BLK -- Blocks Per Game
# - TOV -- Turnovers Per Game
# - PF -- Personal Fouls Per Game
# - PTS -- Points Per Game

# %% [markdown]
# ### Import

# %%
import missingno as msno
from sklearn.impute import SimpleImputer

# %%
nba_df = pd.read_csv('nba_data.csv')
nba_df
# Out:
#                   Player  AllStar  Season   age Team League  Pos     G    GS  \
# 0         Alaa Abdelnaby        0    1990  22.0  POR    NBA   PF  43.0   0.0
# 1         Alaa Abdelnaby        0    1991  23.0  POR    NBA   PF  71.0   1.0
# 2         Alaa Abdelnaby        0    1992  24.0  TOT    NBA   PF  75.0  52.0
# 3         Alaa Abdelnaby        0    1992  24.0  MIL    NBA   PF  12.0   0.0
# 4         Alaa Abdelnaby        0    1992  24.0  BOS    NBA   PF  63.0  52.0
# ...                  ...      ...     ...   ...  ...    ...  ...   ...   ...
# 24517       George Zídek        0    1997  24.0  SEA    NBA    C   6.0   0.0
# 24518  Derrick Zimmerman        0    2005  24.0  NJN    NBA   PG   2.0   0.0
# 24519           Jim Zoet        0    1982  29.0  DET    NBA    C   7.0   0.0
# 24520          Bill Zopf        0    1970  22.0  MIL    NBA   PG  53.0   NaN
# 24521         Matt Zunic        0    1948  29.0  WSC    BAA  NaN  56.0   NaN
#
# ...

# %% [markdown]
# ### Null data

# %%
msno.matrix(nba_df)
plt.show()

# %% [markdown]
# ### Delete null Position data

# %%
nba_df = nba_df[nba_df['Pos'].isnull() != True].reset_index(drop=True)
nba_df
# Out:
#                   Player  AllStar  Season   age Team League Pos     G    GS  \
# 0         Alaa Abdelnaby        0    1990  22.0  POR    NBA  PF  43.0   0.0
# 1         Alaa Abdelnaby        0    1991  23.0  POR    NBA  PF  71.0   1.0
# 2         Alaa Abdelnaby        0    1992  24.0  TOT    NBA  PF  75.0  52.0
# 3         Alaa Abdelnaby        0    1992  24.0  MIL    NBA  PF  12.0   0.0
# 4         Alaa Abdelnaby        0    1992  24.0  BOS    NBA  PF  63.0  52.0
# ...                  ...      ...     ...   ...  ...    ...  ..   ...   ...
# 23343       George Zídek        0    1997  24.0  DEN    NBA   C   6.0   0.0
# 23344       George Zídek        0    1997  24.0  SEA    NBA   C   6.0   0.0
# 23345  Derrick Zimmerman        0    2005  24.0  NJN    NBA  PG   2.0   0.0
# 23346           Jim Zoet        0    1982  29.0  DET    NBA   C   7.0   0.0
# 23347          Bill Zopf        0    1970  22.0  MIL    NBA  PG  53.0   NaN
#
# ...

# %%
msno.matrix(nba_df)

# %% [markdown]
# ### Replace '-' value to 0

# %%
nba_df.replace(np.nan, 0, inplace=True)

# %%
nba_df
# Out:
#                   Player  AllStar  Season   age Team League Pos     G    GS  \
# 0         Alaa Abdelnaby        0    1990  22.0  POR    NBA  PF  43.0   0.0
# 1         Alaa Abdelnaby        0    1991  23.0  POR    NBA  PF  71.0   1.0
# 2         Alaa Abdelnaby        0    1992  24.0  TOT    NBA  PF  75.0  52.0
# 3         Alaa Abdelnaby        0    1992  24.0  MIL    NBA  PF  12.0   0.0
# 4         Alaa Abdelnaby        0    1992  24.0  BOS    NBA  PF  63.0  52.0
# ...                  ...      ...     ...   ...  ...    ...  ..   ...   ...
# 23343       George Zídek        0    1997  24.0  DEN    NBA   C   6.0   0.0
# 23344       George Zídek        0    1997  24.0  SEA    NBA   C   6.0   0.0
# 23345  Derrick Zimmerman        0    2005  24.0  NJN    NBA  PG   2.0   0.0
# 23346           Jim Zoet        0    1982  29.0  DET    NBA   C   7.0   0.0
# 23347          Bill Zopf        0    1970  22.0  MIL    NBA  PG  53.0   0.0
#
# ...

# %%
nba_df.columns
# Out:
# Index(['Player', 'AllStar', 'Season', 'age', 'Team', 'League', 'Pos', 'G',
#        'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK', 'TOV',
#        'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ### Change object type to int type

# %%
nba_df[['MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK', 'TOV', 'PF', 'PTS']] = nba_df[['MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'BLK', 'TOV', 'PF', 'PTS']].astype(str).astype(float)

# %%
nba_df[['Season', 'age', 'G', 'GS']] = nba_df[['Season', 'age', 'G', 'GS']].astype(int)

# %% [markdown]
# ### Delete all other League players other than NBA

# %%
nba_df = nba_df[nba_df['League']=='NBA'].reset_index(drop=True)

# %% [markdown]
# ### Describe dataset

# %%
nba_df.describe()
# Out:
#             AllStar        Season           age             G            GS  \
# count  21742.000000  21742.000000  21742.000000  21742.000000  21742.000000
# mean       0.068163   1990.125517     26.958651     50.756646     16.522767
# std        0.252031     16.059621      3.861153     26.605477     26.222241
# min        0.000000   1949.000000     18.000000      0.000000      0.000000
# 25%        0.000000   1979.000000     24.000000     27.000000      0.000000
# 50%        0.000000   1993.000000     26.000000     57.000000      1.000000
# 75%        0.000000   2003.000000     30.000000     76.000000     23.000000
# max        1.000000   2018.000000     44.000000     88.000000     83.000000
#
#                  MP            FG           FGA           FG%            3P  \
# count  21742.000000  21742.000000  21742.000000  21742.000000  21742.000000
# mean      19.983645      3.157939      7.077872      0.429199      0.246251
# ...

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 31 columns):
# Player     21742 non-null object
# AllStar    21742 non-null int64
# Season     21742 non-null int32
# age        21742 non-null int32
# Team       21742 non-null object
# League     21742 non-null object
# Pos        21742 non-null object
# G          21742 non-null int32
# GS         21742 non-null int32
# MP         21742 non-null float64
# FG         21742 non-null float64
# FGA        21742 non-null float64
# FG%        21742 non-null float64
# 3P         21742 non-null float64
# 3PA        21742 non-null float64
# 3P%        21742 non-null float64
# 2P         21742 non-null float64
# 2PA        21742 non-null float64
# 2P%        21742 non-null float64
# eFG%       21742 non-null float64
# FT         21742 non-null float64
# FTA        21742 non-null float64
# FT%        21742 non-null float64
# ORB        21742 non-null float64
# ...

# %% [markdown]
# ### Drop League column and Team column

# %%
nba_df.drop(['League', 'Team'], axis=1, inplace=True)

# %% [markdown]
# ### AllStar Count

# %%
sns.countplot(x='AllStar', data=nba_df)

# %% [markdown]
# ### Position Count
# - There are some players that play for multiple positions

# %%
sns.countplot(x='Pos', data=nba_df)

# %% [markdown]
# ### PTS comparison (AllStar and non-AllStar)
# - All-Star players score about 20 points avg
# - Non All-Star players score about 7 points avg

# %%
sns.barplot(x="AllStar", y="PTS", data=nba_df)

# %% [markdown]
# ### Age comparison (AllStar and non-AllStar)
# - Both have similar distribution rate.
# - Age doesn't seem important for All-Star classification

# %%
sns.barplot(x="AllStar", y="age", data=nba_df)

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
nba_df['AllStar'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)

ax[0].set_title('Pie plot - All-Star')
ax[0].set_ylabel('')
sns.countplot('AllStar', data=nba_df, ax=ax[1])
ax[1].set_title('Count plot - All-Star')

plt.show()

# %% [markdown]
# ### Number of All-Star player per Season
# - Number of All-Star players in some season is less than 5.
# - Season could be excluded from training since the data is wrong
# - Players are nominated for All-Star on their abilities so season can be unneccessary

# %%
plt.figure(figsize=(18,15))
sns.countplot(x='Season', data=nba_df[nba_df['AllStar']==1])
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.title("Number of NBA players per Season", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Number of NBA players per Season')

# %%
nba_df[nba_df['Season']==2018]#[nba_df[nba_df['Season']==1998]['AllStar']==1]
# Out:
#                  Player  AllStar  Season  age Pos   G  GS    MP   FG   FGA  \
# 2956      José Calderón        0    2018   37  PG  49   0  12.9  0.9   2.4
# 3779    Darren Collison        0    2018   31  PG  76  76  28.2  4.1   8.7
# 4891          Luol Deng        0    2018   33  SF  22   2  17.8  2.7   5.4
# 6455      Channing Frye        0    2018   35   C  36   6   9.5  1.2   3.3
# 7088      Marcin Gortat        0    2018   34   C  47  43  16.0  2.1   4.0
# 11473  Shaun Livingston        0    2018   33  PG  64   0  15.1  1.7   3.3
# 14304     Dirk Nowitzki        1    2018   40  PF  51  20  15.6  2.6   7.4
# 14712     Zaza Pachulia        0    2018   34   C  68   3  12.9  1.3   2.8
# 14857       Tony Parker        0    2018   36  PG  56   0  17.9  3.8   8.3
# 19777       Dwyane Wade        1    2018   37  SG  72   2  26.2  5.8  13.3
#
#        ...    FT%  ORB  DRB  TRB  AST  BLK  TOV   PF   PTS  Season_le
# 2956   ...  0.818  0.2  1.0  1.2  2.3  0.1  0.7  1.3   2.3         69
# ...

# %%
nba_df[nba_df['Player']=="Kobe Bryant"]
# Out:
#            Player  AllStar  Season  age Pos   G  GS    MP    FG   FGA  ...  \
# 2627  Kobe Bryant        0    1996   18  SF  71   6  15.5   2.5   5.9  ...
# 2628  Kobe Bryant        1    1997   19  SF  79   1  26.0   4.9  11.6  ...
# 2629  Kobe Bryant        0    1998   20  SG  50  50  37.9   7.2  15.6  ...
# 2630  Kobe Bryant        1    1999   21  SG  66  62  38.2   8.4  17.9  ...
# 2631  Kobe Bryant        1    2000   22  SG  68  68  40.9  10.3  22.2  ...
# 2632  Kobe Bryant        1    2001   23  SG  80  80  38.3   9.4  20.0  ...
# 2633  Kobe Bryant        1    2002   24  SG  82  82  41.5  10.6  23.5  ...
# 2634  Kobe Bryant        1    2003   25  SG  65  64  37.6   7.9  18.1  ...
# 2635  Kobe Bryant        1    2004   26  SG  66  66  40.7   8.7  20.1  ...
# 2636  Kobe Bryant        1    2005   27  SG  80  80  41.0  12.2  27.2  ...
# 2637  Kobe Bryant        1    2006   28  SG  77  77  40.8  10.6  22.8  ...
# ...

# %% [markdown]
# ### Correlation Heatmap

# %%
nba_df.corr()
# Out:
#           AllStar    Season       age         G        GS        MP        FG  \
# AllStar  1.000000 -0.150698  0.056449  0.227837  0.207633  0.415107  0.522284
# Season  -0.150698  1.000000  0.173984 -0.182403  0.265352 -0.089089 -0.173131
# age      0.056449  0.173984  1.000000  0.026032  0.095426  0.114277  0.033831
# G        0.227837 -0.182403  0.026032  1.000000  0.458559  0.619501  0.555596
# GS       0.207633  0.265352  0.095426  0.458559  1.000000  0.597101  0.514225
# MP       0.415107 -0.089089  0.114277  0.619501  0.597101  1.000000  0.878633
# FG       0.522284 -0.173131  0.033831  0.555596  0.514225  0.878633  1.000000
# FGA      0.511610 -0.209883  0.034681  0.534040  0.479738  0.876976  0.980835
# FG%      0.111441  0.059413  0.023832  0.354213  0.246996  0.329277  0.357552
# 3P       0.047605  0.381200  0.146549  0.141965  0.363792  0.313694  0.232842
# 3PA      0.045570  0.408282  0.141892  0.126144  0.371069  0.316779  0.233816
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=nba_df.corr(), annot=True)

# %% [markdown]
# ### Transform Categorical data using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(nba_df['Pos'])
nba_df['Pos'] = le.transform(nba_df['Pos'])
nba_df.head()
# Out:
#            Player  AllStar  Season  age  Pos   G  GS    MP   FG  FGA  ...  \
# 0  Alaa Abdelnaby        0    1990   22    3  43   0   6.7  1.3  2.7  ...
# 1  Alaa Abdelnaby        0    1991   23    3  71   1  13.2  2.5  5.1  ...
# 2  Alaa Abdelnaby        0    1992   24    3  75  52  17.5  3.3  6.3  ...
# 3  Alaa Abdelnaby        0    1992   24    3  12   0  13.3  2.2  4.7  ...
# 4  Alaa Abdelnaby        0    1992   24    3  63  52  18.3  3.5  6.6  ...
#
#      FT%  ORB  DRB  TRB  AST  BLK  TOV   PF  PTS  Season_le
# 0  0.568  0.6  1.4  2.1  0.3  0.3  0.5  0.9  3.1         41
# 1  0.752  1.1  2.5  3.7  0.4  0.2  0.9  1.9  6.1         42
# 2  0.759  1.7  2.8  4.5  0.4  0.3  1.3  2.5  7.7         43
# 3  0.750  1.0  2.1  3.1  0.8  0.3  1.1  2.0  5.3         43
# 4  0.760  1.8  3.0  4.8  0.3  0.3  1.3  2.6  8.2         43
#
# [5 rows x 30 columns]

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
le_name_mapping
# Out:
# {'C': 0,
#  'C-PF': 1,
#  'C-SF': 2,
#  'PF': 3,
#  'PF-C': 4,
#  'PF-SF': 5,
#  'PG': 6,
#  'PG-SF': 7,
#  'PG-SG': 8,
#  'SF': 9,
#  'SF-PF': 10,
#  'SF-PG': 11,
#  'SF-SG': 12,
#  'SG': 13,
#  'SG-PF': 14,
#  'SG-PG': 15,
#  'SG-SF': 16}

# %%
nba_df
# Out:
#                   Player  AllStar  Season  age  Pos   G  GS    MP   FG  FGA  \
# 0         Alaa Abdelnaby        0    1990   22    3  43   0   6.7  1.3  2.7
# 1         Alaa Abdelnaby        0    1991   23    3  71   1  13.2  2.5  5.1
# 2         Alaa Abdelnaby        0    1992   24    3  75  52  17.5  3.3  6.3
# 3         Alaa Abdelnaby        0    1992   24    3  12   0  13.3  2.2  4.7
# 4         Alaa Abdelnaby        0    1992   24    3  63  52  18.3  3.5  6.6
# ...                  ...      ...     ...  ...  ...  ..  ..   ...  ...  ...
# 21737       George Zídek        0    1997   24    0   6   0   7.0  0.7  2.5
# 21738       George Zídek        0    1997   24    0   6   0   3.7  0.5  2.3
# 21739  Derrick Zimmerman        0    2005   24    6   2   0  16.0  1.0  1.5
# 21740           Jim Zoet        0    1982   29    0   7   0   4.3  0.1  0.7
# 21741          Bill Zopf        0    1970   22    6  53   0   7.5  0.9  2.5
#
# ...

# %% [markdown]
# ### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit_transform(X.drop(['Pos', 'age']))

# %% [markdown]
# ### Model Train
# - Decision Tree
# - Logistic Regression
# - Random Forest
# - Boosting

# %%
from sklearn.model_selection import train_test_split

X = nba_df.drop(['Season', 'AllStar', 'Player'], axis=1)
Y = nba_df['AllStar']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=13)

# %%
X.shape
# Out:
# (21742, 26)

# %%
Y.shape
# Out:
# (21742,)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt = DecisionTreeClassifier(max_depth=4, random_state=13)
dt.fit(X_train, y_train)

pred = dt.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.9489537824787307

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=13, solver='liblinear')
lr.fit(X_train, y_train)

pred = lr.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.9604506783168545

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=13, n_estimators=100, max_depth=4)
rf.fit(X_train, y_train)

pred = rf.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.9521729133134054
